# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
dataset = pd.read_excel('deliveries.xlsx')

# %%
dataset
# Out:
#     Trip Region  REGA  Parcels  TruckAge  Minutes
# 0      1      B     0       42         3    489.4
# 1      2      B     0       46        11    461.9
# 2      3      A     1       34         9    447.9
# 3      4      A     1       44         1    506.6
# 4      5      B     0       30        13    303.0
# 5      6      A     1       30         7    415.1
# 6      7      A     1       48         2    546.3
# 7      8      B     0       32         1    273.1
# 8      9      B     0       44         7    419.0
# 9     10      A     1       40         4    486.2
# 10    11      B     0       36        15    367.7
# 11    12      B     0       42         2    380.6
# 12    13      B     0       38         1    333.5
# 13    14      B     0       26        14    264.9
# 14    15      A     1       24        11    347.0
# 15    16      A     1       22        12    321.3
# 16    17      A     1       26        14    381.4
# 17    18      B     0       20        15    216.7
# 18    19      A     1       38         6    488.9
# 19    20      B     0       48        10    474.4
# 20    21      A     1       36         8    464.4
# 21    22      A     1       28        15    413.5
# 22    23      B     0       22         3    196.1
# 23    24      A     1       20        15    315.7
# 24    25      B     0       34         9    330.3
# 25    26      B     0       40         7    388.0
# 26    27      B     0       28         5    264.1
# 27    28      B     0       24         6    228.6
# 28    29      A     1       32         9    434.0
# 29    30      A     1       46         1    517.9

# %%
len(dataset)
# Out:
# 30

# %%
dataset.shape
# Out:
# (30, 6)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(dataset['Parcels'],dataset['Minutes'])
plt.title("Scatter Plot of Number of Parclels with Total Travel Minutes")
plt.xlabel("Parcels")
plt.ylabel("Minutes")
# Out:
# Text(0, 0.5, 'Minutes')

# %%
plt.scatter(dataset['Region'],dataset['Minutes'])
plt.xlabel("Region")
plt.ylabel("Minutes")
# Out:
# Text(0, 0.5, 'Minutes')

# %%
plt.scatter(dataset['TruckAge'],dataset['Minutes'])
plt.xlabel("TruckAge")
plt.ylabel("Minutes")
# Out:
# Text(0, 0.5, 'Minutes')

# %%
plt.scatter(dataset['REGA'],dataset['Minutes'])

plt.xlabel("REGA")
plt.ylabel("Minutes")
# Out:
# Text(0, 0.5, 'Minutes')

# %%
dataset['Region'] = np.where(dataset['Region']=='A',0,1)

# %%
dataset
# Out:
#     Trip  Region  REGA  Parcels  TruckAge  Minutes
# 0      1       1     0       42         3    489.4
# 1      2       1     0       46        11    461.9
# 2      3       0     1       34         9    447.9
# 3      4       0     1       44         1    506.6
# 4      5       1     0       30        13    303.0
# 5      6       0     1       30         7    415.1
# 6      7       0     1       48         2    546.3
# 7      8       1     0       32         1    273.1
# 8      9       1     0       44         7    419.0
# 9     10       0     1       40         4    486.2
# 10    11       1     0       36        15    367.7
# 11    12       1     0       42         2    380.6
# 12    13       1     0       38         1    333.5
# 13    14       1     0       26        14    264.9
# 14    15       0     1       24        11    347.0
# 15    16       0     1       22        12    321.3
# 16    17       0     1       26        14    381.4
# 17    18       1     0       20        15    216.7
# 18    19       0     1       38         6    488.9
# 19    20       1     0       48        10    474.4
# 20    21       0     1       36         8    464.4
# 21    22       0     1       28        15    413.5
# 22    23       1     0       22         3    196.1
# 23    24       0     1       20        15    315.7
# 24    25       1     0       34         9    330.3
# 25    26       1     0       40         7    388.0
# 26    27       1     0       28         5    264.1
# 27    28       1     0       24         6    228.6
# 28    29       0     1       32         9    434.0
# 29    30       0     1       46         1    517.9

# %%
dataset.drop(columns=['Trip'])
# Out:
#     Region  REGA  Parcels  TruckAge  Minutes
# 0        1     0       42         3    489.4
# 1        1     0       46        11    461.9
# 2        0     1       34         9    447.9
# 3        0     1       44         1    506.6
# 4        1     0       30        13    303.0
# 5        0     1       30         7    415.1
# 6        0     1       48         2    546.3
# 7        1     0       32         1    273.1
# 8        1     0       44         7    419.0
# 9        0     1       40         4    486.2
# 10       1     0       36        15    367.7
# 11       1     0       42         2    380.6
# 12       1     0       38         1    333.5
# 13       1     0       26        14    264.9
# 14       0     1       24        11    347.0
# 15       0     1       22        12    321.3
# 16       0     1       26        14    381.4
# 17       1     0       20        15    216.7
# 18       0     1       38         6    488.9
# 19       1     0       48        10    474.4
# 20       0     1       36         8    464.4
# 21       0     1       28        15    413.5
# 22       1     0       22         3    196.1
# 23       0     1       20        15    315.7
# 24       1     0       34         9    330.3
# 25       1     0       40         7    388.0
# 26       1     0       28         5    264.1
# 27       1     0       24         6    228.6
# 28       0     1       32         9    434.0
# 29       0     1       46         1    517.9

# %%
dependant_variable = 'Minutes'
independant_variables = dataset.columns.tolist()

# %%
#independant_variables.remove(dependant_variable)
#independant_variables.remove('Trip')
independant_variables.remove('REGA')

# %%
independant_variables
# Out:
# ['Region', 'Parcels', 'TruckAge']

# %%
x = dataset[independant_variables].values
x
# Out:
# array([[ 1, 42,  3],
#        [ 1, 46, 11],
#        [ 0, 34,  9],
#        [ 0, 44,  1],
#        [ 1, 30, 13],
#        [ 0, 30,  7],
#        [ 0, 48,  2],
#        [ 1, 32,  1],
#        [ 1, 44,  7],
#        [ 0, 40,  4],
#        [ 1, 36, 15],
#        [ 1, 42,  2],
#        [ 1, 38,  1],
#        [ 1, 26, 14],
#        [ 0, 24, 11],
#        [ 0, 22, 12],
#        [ 0, 26, 14],
#        [ 1, 20, 15],
#        [ 0, 38,  6],
#        [ 1, 48, 10],
#        [ 0, 36,  8],
#        [ 0, 28, 15],
#        [ 1, 22,  3],
#        [ 0, 20, 15],
#        [ 1, 34,  9],
#        [ 1, 40,  7],
#        [ 1, 28,  5],
#        [ 1, 24,  6],
#        [ 0, 32,  9],
#        [ 0, 46,  1]], dtype=int64)

# %%
y = dataset[dependant_variable].values
y
# Out:
# array([489.4, 461.9, 447.9, 506.6, 303. , 415.1, 546.3, 273.1, 419. ,
#        486.2, 367.7, 380.6, 333.5, 264.9, 347. , 321.3, 381.4, 216.7,
#        488.9, 474.4, 464.4, 413.5, 196.1, 315.7, 330.3, 388. , 264.1,
#        228.6, 434. , 517.9])

# %%
X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size=0.2)

# %%
#scaler = MinMaxScaler()
#X_train = scaler.fit_transform(X_train)
#X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[ 1, 42,  3],
#        [ 1, 48, 10],
#        [ 0, 38,  6],
#        [ 1, 42,  2],
#        [ 1, 26, 14],
#        [ 1, 34,  9]], dtype=int64)

# %%
regressor = LinearRegression()
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
y_pred
# Out:
# array([386.80813962, 471.62780942, 469.90590054, 383.05081697,
#        272.08959215, 331.32752721])

# %%
test = regressor.predict([[0,42,3]])
test
# Out:
# array([497.64620674])

# %%
dataset.head()
# Out:
#    Trip  Region  REGA  Parcels  TruckAge  Minutes
# 0     1       1     0       42         3    489.4
# 1     2       1     0       46        11    461.9
# 2     3       0     1       34         9    447.9
# 3     4       0     1       44         1    506.6
# 4     5       1     0       30        13    303.0
